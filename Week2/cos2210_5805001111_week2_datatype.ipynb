# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
# ***Ex1*** My electricity bills for the last three months have been \$23, \$32 and \$64. What is the average
# monthly electricity bill over the three month period? Write an expression to calculate the mean, and
# use **print()** to view the result.

# %%
# Write an expression that calculates the average of 23, 32 and 64
# Place the expression in this print statement
print((23+32+64)/3.0)
# Out:
# 39.666666666666664

# %% [markdown]
# ***Ex2*** Two parts of a
#
# oor need tiling. One part is 9 tiles wide by 7 tiles long, the other is 5 tiles wide
#
# by 7 tiles long. Tiles come in packages of 6.
#
# How many tiles are needed?
#
# You buy 17 packages of tiles containing 6 tiles each. How many tiles will be left over?

# %%
# Fill this in with an expression that calculates how many tiles are needed.
print(9*7+5*7)

# Fill this in with an expression that calculates how many tiles will be left over.
print((17*6)-(9*7+5*7))
# Out:
# 98
# 4

# %% [markdown]
# ***Ex3*** Which of these lines of Python code are well formatted?
#
#
# *   print(((3+ 32)) + -15//2)
# *  **print((17 - 6)%(5 + 2))**
# *  print((1 + 2 +4) / 13)
# * **print(4/2 - 7*7)**

# %% [markdown]
# ***Ex4*** Write code to compare these densities. Is the population of San Francisco more dense than
# that of Rio dejnerio? Print True if it is and False if not

# %%
sf_population, sf_area = 864816, 231.89
rio_population, rio_area = 6453682, 486.5

# %%
san_francisco_pop_density = sf_population/sf_area
rio_de_janeiro_pop_density = rio_population/rio_area

# %%
# Short form
print(san_francisco_pop_density > rio_de_janeiro_pop_density)
# Out:
# False

# %%
# Better understanding form
if (san_francisco_pop_density > rio_de_janeiro_pop_density):
  print("True")
else:
  print("False")
# Out:
# False

# %% [markdown]
# # String

# %% [markdown]
# ***Ex5*** String Concatenation

# %%
first_word = 'Hello'
second_word = 'There'
print(first_word + second_word)
# Out:
# HelloThere

# %%
print(first_word + ' ' + second_word)
# Out:
# Hello There

# %%
print(first_word*5)
# Out:
# HelloHelloHelloHelloHello

# %%
print(len(first_word))
# Out:
# 5

# %% [markdown]
# ***Ex6*** Fix this string!

# %%
ford_quote = 'Whether you think you can, or you think you can\'t--you\'re right.'

# %%
print("9" + str(9))
# Out:
# 99

# %% [markdown]
# ***Ex7*** String concatenation

# %%
coconut_count = "34"
mango_count = "15"
tropical_fruit_count = coconut_count + mango_count
print(tropical_fruit_count)
# Out:
# 3415

# %% [markdown]
# # Data type

# %% [markdown]
# ***Ex8 ***print data types

# %%
print(type(633))
print(type("633"))
print(type(633.0))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
count = int(4.0)
print(count)
print(type(count))
# Out:
# 4
# <class 'int'>

# %%
house_number = 13
street_name = "The crescent"
town_name = "Belmont"
print(type(house_number))
# Out:
# <class 'int'>

# %%
address = str(house_number) + " " + street_name +", " + town_name
print(address)
# Out:
# 13 The crescent, Belmont

# %% [markdown]
# # Method (buit-in function for strings)

# %%
print("Put Phapon".title())
# Out:
# Put Phapon

# %%
full_name = "Put Phapon"
print(full_name.islower())
# Out:
# False

# %%
print("One fish, two fish, red fish, blue fish.".count('fish'))
# Out:
# 4
