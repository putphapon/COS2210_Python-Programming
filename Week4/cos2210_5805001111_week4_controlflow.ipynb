# %% [markdown]
# # if-condition

# %%
phone_balance = 8
bank_balance = 100
print(phone_balance, bank_balance)
# Out:
# 8 100

# %%
# indentation
if phone_balance < 5:
  phone_balance += 10
  bank_balance -= 10
print(phone_balance, bank_balance)
# Out:
# 8 100

# %%
n = 4

if n % 2 == 0:
  print("Number " + str(n) + " is even.")
else:
  print("Number " + str(n) + " is odd.")
print(n)
# Out:
# Number 4 is even.
# 4

# %%
n = 15

if n % 2 == 0:
  print("Number " + str(n) + " is even.")
else:
  print("Number " + str(n) + " is odd.")
print(n)
# Out:
# Number 15 is odd.
# 15

# %%
season = "spring"

if season == "spring":
  print("plant the garden!")
elif season == "summer":
  print("water the garden!")
elif season == "fall":
  print("harvest the garden!")
elif season == "winter":
  print("stay indoors!")
else:
  print("unrecognized season")
# Out:
# plant the garden!

# %%
# Bus fares
age = 35

# Here are the age limits for bus fares
free_up_to_age = 4
child_up_to_age = 18
senior_from_age = 65

# These lines determine the bus fare prices
concession_ticket = 1.25
adult_ticket = 2.50

# Here is the logic for bus fare prices
if age <= free_up_to_age:
  ticket_price = 0
elif age <= child_up_to_age:
  ticket_price = concession_ticket
elif age >= senior_from_age:
  ticket_price = concession_ticket
else:
  ticket_price = adult_ticket


message = "Somebody who is {} years old will pay ${} to ride the bus.".format(age, ticket_price)
print(message)
# Out:
# Somebody who is 35 years old will pay $2.5 to ride the bus.

# %% [markdown]
# # Complex boolean expressions

# %%
#### Do Not Run ####

# %%
# if 18.5 <= weight / height**2 < 25:
#   print("BMI is considered 'normal'")

# %%
# if is_raining and is_sunny:
#   print("Is there a rainbow?")

# %%
# if (not unsubscribed) and (location == "USA" or location == "CAN"):
#   print("send email")

# %% [markdown]
# # For Loops

# %%
cities = ['new york city', 'mountain view', 'chicago', 'los angeles']

for city in cities:
  print(city.title()) # string .title()
# Out:
# New York City
# Mountain View
# Chicago
# Los Angeles

# %%
cities = ['new york city', 'mountain view', 'chicago', 'los angeles']

capitalized_citites = []

for city in cities:
  capitalized_citites.append(city.title())
print(capitalized_citites)
# Out:
# ['New York City', 'Mountain View', 'Chicago', 'Los Angeles']

# %% [markdown]
# ## range()

# %%
print(list(range(4)))
# Out:
# [0, 1, 2, 3]

# %%
print(list(range(2,6)))
# Out:
# [2, 3, 4, 5]

# %%
print(list(range(1,10,2)))
# Out:
# [1, 3, 5, 7, 9]

# %%
for number in range(4):
  print(number)
# Out:
# 0
# 1
# 2
# 3

# %%
cities = ['new york city', 'mountain view', 'chicago', 'los angeles']

for index in range(len(cities)):
  cities[index] = cities[index].title()
print(cities)
# Out:
# ['New York City', 'Mountain View', 'Chicago', 'Los Angeles']

# %% [markdown]
# ## Building dictionary

# %%
book_title = ['great', 'expectations','the', 'adventures', 'of', 'sherlock','holmes','the']
word_counter = {}

for word in book_title:
  word_counter[word] = word_counter.get(word, 0) + 1
print(word_counter)
# Out:
# {'great': 1, 'expectations': 1, 'the': 2, 'adventures': 1, 'of': 1, 'sherlock': 1, 'holmes': 1}

# %% [markdown]
# ## Iterating through dictionaries

# %%
cast = {
            "Jerry Seinfeld": "Jerry Seinfeld",
            "Julia Louis-Dreyfus": "Elaine Benes",
            "Jason Alexander": "George Costanza",
            "Michael Richards": "Cosmo Kramer"
          }

print("Iterating through keys:")

for key in cast:
  print(key)
# Out:
# Iterating through keys:
# Jerry Seinfeld
# Julia Louis-Dreyfus
# Jason Alexander
# Michael Richards

# %%
print("\nIterating through keys and values:")
for key, value in cast.items():
  print("Actor: {} Role: {}".format(key, value))
# Out:
# Iterating through keys and values:
# Actor: Jerry Seinfeld Role: Jerry Seinfeld
# Actor: Julia Louis-Dreyfus Role: Elaine Benes
# Actor: Jason Alexander Role: George Costanza
# Actor: Michael Richards Role: Cosmo Kramer

# %% [markdown]
# # While

# %%
card_deck = [4, 11, 8, 5, 13, 2, 8, 10]
hand = []

# adds the last element of the card_deck list to the hand list
# until the values in hand add up to 17 or more
while sum(hand) < 17:
  hand.append(card_deck.pop())
print(hand)
# Out:
# [10, 8]

# %%
# Your code should add up the odd numbers in the list, but only up to the first 5 odd numbers
# If there are more than 5 odd numbers, you should stop at the fifth. If there are fewer than
num_list = [422, 136, 524, 85, 96, 719, 85, 92, 10, 17, 312, 542, 87, 23, 86, 191, 116, 35, 1]
count_odd = 0
list_sum = 0
i = 0
len_num_list = len(num_list)

while (count_odd < 5) and (i < len_num_list):
  if num_list[i] % 2 != 0:
    list_sum += num_list[i]
    count_odd += 1
  i += 1
print ("The numbers of odd numbers added are: {}".format(count_odd))
print ("The sum of the odd numbers added is: {}".format(list_sum))
# Out:
# The numbers of odd numbers added are: 5
# The sum of the odd numbers added is: 993

# %% [markdown]
# ## Break, Continue

# %%
manifest = [("bananas", 15), ("mattresses", 24), ("dog kennels", 42), ("machine", 120)]

# %%
# the code breaks the loop when weight exceeds or reaches the limit
print("METHOD 1")

weight = 0
items = []

for cargo_name, cargo_weight in manifest:
  print("current weight: {}".format(weight))
  if weight >= 100:
    print(" breaking loop now!")
    break
  else:
    print(" adding {} ({})".format(cargo_name, cargo_weight))
    items.append(cargo_name)
    weight += cargo_weight

print("\nFinal Weight: {}".format(weight))
print("Final Items: {}".format(items))

# skips an iteration when adding an item would exceed the limit
# breaks the loop if weight is exactly the value of the limit
print("\nMETHOD 2")

weight = 0
items = []

for cargo_name, cargo_weight in manifest:
  print("current weight: {}".format(weight))
  if weight >= 100:
    print(" breaking from the loop now!")
    break
  elif weight + cargo_weight > 100:
    print(" skipping {} ({})".format(cargo_name, cargo_weight))
    continue
  else:
    print(" adding {} ({})".format(cargo_name, cargo_weight))
    items.append(cargo_name)
    weight += cargo_weight

print("\nFinal Weight: {}".format(weight))
print("Final Items: {}".format(items))
# Out:
# METHOD 1
# current weight: 0
#  adding bananas (15)
# current weight: 15
#  adding mattresses (24)
# current weight: 39
#  adding dog kennels (42)
# current weight: 81
#  adding machine (120)
#
# Final Weight: 201
# Final Items: ['bananas', 'mattresses', 'dog kennels', 'machine']
#
# METHOD 2
# current weight: 0
#  adding bananas (15)
# current weight: 15
#  adding mattresses (24)
# current weight: 39
#  adding dog kennels (42)
# current weight: 81
#  skipping machine (120)
#
# Final Weight: 81
# Final Items: ['bananas', 'mattresses', 'dog kennels']

# %% [markdown]
# ## Zip and Enumerate

# %%
#manifest = [("bananas", 15), ("mattresses", 24), ("dog kennels", 42), ("machine", 120)]
items = ['bananas', 'matresses', 'dog kennels', 'machine', 'cheese']
weights = [15, 34, 42, 120, 5]

# %%
for cargo in zip(items, weights):
  print(cargo[0], cargo[1])
# Out:
# bananas 15
# matresses 34
# dog kennels 42
# machine 120
# cheese 5

# %%
items, weights = zip(*manifest)
print(items)
print(weights)
# Out:
# ('bananas', 'mattresses', 'dog kennels', 'machine')
# (15, 24, 42, 120)

# %%
items = ['bananas', 'matresses', 'dog kennels', 'machine', 'cheese']

# %%
for i, item in zip(range(len(items)), items):
  print(i, item)
# Out:
# 0 bananas
# 1 matresses
# 2 dog kennels
# 3 machine
# 4 cheese

# %% [markdown]
# ## List Comprehensions

# %%
cities = ['new york city', 'mountain view', 'chicago', 'los angeles']

capitalized_citites = []
for city in cities:
  capitalized_citites.append(city.title())
print(capitalized_citites)
# Out:
# ['New York City', 'Mountain View', 'Chicago', 'Los Angeles']

# %%
capitalized_citites = [city.title() for city in cities]
print(capitalized_citites)
# Out:
# ['New York City', 'Mountain View', 'Chicago', 'Los Angeles']

# %%
squares = []
for x in range(9):
  squares.append(x**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64]

# %%
squares = [x**2 for x in range(9)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64]

# %%
squares = [x**2 if x % 2 == 0 else x + 3 for x in range(9)]
print(squares)
# Out:
# [0, 4, 4, 6, 16, 8, 36, 10, 64]
